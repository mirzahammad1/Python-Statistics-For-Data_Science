# %% [markdown]
# # T-Test
#
# When is it used:
#
# 1- When we want to determine if means of 2 groups are different or not
# 2- When we want to compare means of two samples
# 3- Sample size <=30
# 4- Data follows normal distribution
#
# Independent Sample T-Test:
#
# 1- Check the average of 2 independent unrelated groups
# 2- Samples should be from 2 different populations
# • Null Hypothesis: mu_{a} = mu_{b}
# • Alternate Hypothesis: mu_{a} ne mu b
#
# Paired Sample T-Test:
#
# 1- Average of 2 samples taken from the same population but in different points in time.
# • Null Hypothesis mu_{1} = 0 Alternate Hypothesis: mu angle #0
#
# One Sample T-Test:
#
# 1- Average of a single group is different from known average
#  Null Hypothesis mu_{2} = X
#  Alternate Hypothesis: mu_{a} X

# %%
import random
a = [ random.gauss(50,20) for x in range (30)]
b = [ random.gauss(55,15) for x in range (30)]

# %%
import seaborn as sns
sns.set_style('darkgrid')
sns.kdeplot(a,shade=True)
sns.kdeplot(b,shade=True)
# Out:
# C:\Users\laptop world\AppData\Local\Temp\ipykernel_14820\373029918.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(a,shade=True)
# C:\Users\laptop world\AppData\Local\Temp\ipykernel_14820\373029918.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(b,shade=True)
# <Axes: ylabel='Density'>

# %%
import scipy.stats as stats
t_stats,p_value = stats.ttest_ind(a,b,equal_var=True)
t_stats,p_value
# Out:
# (-1.4973240534527334, 0.13973163301096334)

# %%
import numpy as np

# %%
np.mean(a),np.mean(b)
# Out:
# (50.002176888281, 56.78588583810462)

# %%
a = [ random.gauss(50,20) for x in range (30)]
b = [ random.gauss(60,25) for x in range (30)]

# %%
t_stats,p_value = stats.ttest_ind(a,b,equal_var=True)
t_stats,p_value
t_stats,p_value
# Out:
# (-0.960266044655554, 0.3448598378305504)

# %%
np.mean(b) - np.mean(a)
# Out:
# 5.357370571052307

# %%
np.mean(a)
# Out:
# 52.33176568835248

# %%
t_stats,p_value = stats.ttest_1samp(a,40,axis=0)
t_stats,p_value
# Out:
# (4.600432691610081, 7.690469819177296e-05)
